# %%
pip install scikit-Learn
# Out:
# Requirement already satisfied: scikit-Learn in c:\users\central computer lab\anaconda3\lib\site-packages (1.0.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: scipy>=1.1.0 in c:\users\central computer lab\anaconda3\lib\site-packages (from scikit-Learn) (1.7.3)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\central computer lab\anaconda3\lib\site-packages (from scikit-Learn) (1.21.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\central computer lab\anaconda3\lib\site-packages (from scikit-Learn) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\central computer lab\anaconda3\lib\site-packages (from scikit-Learn) (1.1.0)

# %%
from skimage import io
import matplotlib.pyplot as plt
url='https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTvAz7oRpSnwGnBO2p64jeZKA6b0ULoNEII0w&usqp=CAU.jpg'
image=io.imread(url)
plt.imshow(image)
plt.show()

# %%
import cv2
import matplotlib.image as mping
import matplotlib.pyplot as plt
img=mping.imread('Z1.jpg')
plt.imshow(img)
plt.show()

# %%
hsv_img=cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
light_brown=(28,84,71)
dark_brown=(30,67,40)
mask=cv2.inRange(img,light_brown,dark_brown)
result=cv2.bitwise_and(img,img,mask-mask)
plt.subplot(1,2,1)
plt.imshow(mask,cmap="gray")
plt.subplot(1,2,2)
plt.imshow(result)
plt.show()

# %%
light_white=(0,0,200)
dark_white=(145,60,255)
mask_white=cv2.inRange(hsv_img,light_white,dark_white)
result_white=cv2.bitwise_and(img,img,mask=mask_white)
plt.subplot(1,2,1)
plt.imshow(mask_white,cmap="gray")
plt.subplot(1,2,2)
plt.imshow(result_white)
plt.show()

# %%
final_mask=mask+mask_white
final_result=cv2.bitwise_and(img,img,mask=final_mask)
plt.subplot(1,2,1)
plt.imshow(final_mask,cmap="gray")
plt.subplot(1,2,2)
plt.imshow(final_result)
plt.show()

# %%
blur=cv2.GaussianBlur(final_result,(7,7),0)
plt.imshow(blur)
plt.show()

# %%
import cv2
import matplotlib.image as mping
import matplotlib.pyplot as plt
img1=cv2.imread('flower2.jpg')
img2=cv2.imread('flower3.jpg')
fimg1=img1+img2
plt.imshow(fimg1)
plt.show()
cv2.imwrite('output.jpg',fimg1)
fimg2=img1-img2
plt.imshow(fimg2)
plt.show()
cv2.imwrite('output.jpg',fimg2)
fimg3=img1*img2
plt.imshow(fimg3)
plt.show()
cv2.imwrite('output.jpg',fimg3)
fimg4=img1/img2
plt.imshow(fimg4)
plt.show()
cv2.imwrite('output.jpg',fimg4)
# Out:
# C:\Users\Central Computer Lab\AppData\Local\Temp\ipykernel_3720\1678536145.py:18: RuntimeWarning: divide by zero encountered in true_divide
#   fimg4=img1/img2
# C:\Users\Central Computer Lab\AppData\Local\Temp\ipykernel_3720\1678536145.py:18: RuntimeWarning: invalid value encountered in true_divide
#   fimg4=img1/img2
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# True
